# %%
import selectors

# %%
selector = selectors.DefaultSelector()

# %%
print(selector._map.items())
# Out:
# ItemsView(<selectors._SelectorMapping object at 0x0000022268C4C3E0>)
# Executing <TimerHandle when=1421328.64 _set_result_unless_cancelled(<Future finis...events.py:448>, None) at c:\Users\shaik\AppData\Local\Programs\Python\Python312\Lib\asyncio\futures.py:311 created at c:\Users\shaik\AppData\Local\Programs\Python\Python312\Lib\asyncio\tasks.py:661> took 0.422 seconds
# Executing <Task pending name='Task-1' coro=<IOPubThread._run_event_pipe_gc() running at C:\Users\shaik\AppData\Roaming\Python\Python312\site-packages\ipykernel\iostream.py:121> wait_for=<Future pending cb=[Task.task_wakeup()] created at c:\Users\shaik\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py:448> created at c:\Users\shaik\AppData\Local\Programs\Python\Python312\Lib\asyncio\tasks.py:695> took 0.219 seconds
# Executing <Handle BaseAsyncIOLoop._handle_events(1184, 1) created at c:\Users\shaik\AppData\Local\Programs\Python\Python312\Lib\asyncio\selector_events.py:280> took 0.687 seconds
# ...
